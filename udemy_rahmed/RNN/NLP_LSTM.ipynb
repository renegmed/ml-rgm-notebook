# %%
import os
#import argparse
#import boto3
import numpy as np
#import tensorflow as tf
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
region = sagemaker_session.boto_session.region_name

# %%
training_data_uri = 's3://sagemaker-us-east-1-731833107751/npl-lstm-data'
print(training_data_uri)
# Out:
# s3://sagemaker-us-east-1-731833107751/npl-lstm-data

# %%
#!pygmentize 'train.py'

# %%
from sagemaker.tensorflow import TensorFlow
estimator = TensorFlow(entry_point='train.py',
                             role=role,
                             train_instance_count=1,
                             train_instance_type='local',
                             #train_instance_type='ml.m5.4xlarge',
                             framework_version='2.0.0',
                             py_version='py3',
                             distributions={'parameter_server': {'enabled': True}})

# %%
estimator.fit(training_data_uri)
# Out:
# Creating tmp1jsw7rhh_algo-1-jpiss_1 ...
# Attaching to tmp1jsw7rhh_algo-1-jpiss_12mdone
# algo-1-jpiss_1  | 2020-02-02 17:46:33,675 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# algo-1-jpiss_1  | 2020-02-02 17:46:33,683 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-jpiss_1  | 2020-02-02 17:46:33,883 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-jpiss_1  | 2020-02-02 17:46:33,904 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-jpiss_1  | 2020-02-02 17:46:33,922 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-jpiss_1  | 2020-02-02 17:46:33,935 sagemaker-containers INFO     Invoking user script
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | Training Env:
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | {
# algo-1-jpiss_1  |     "additional_framework_parameters": {
# algo-1-jpiss_1  |         "sagemaker_parameter_server_enabled": true
# algo-1-jpiss_1  |     },
# algo-1-jpiss_1  |     "channel_input_dirs": {
# algo-1-jpiss_1  |         "training": "/opt/ml/input/data/training"
# algo-1-jpiss_1  |     },
# algo-1-jpiss_1  |     "current_host": "algo-1-jpiss",
# algo-1-jpiss_1  |     "framework_module": "sagemaker_tensorflow_container.training:main",
# algo-1-jpiss_1  |     "hosts": [
# algo-1-jpiss_1  |         "algo-1-jpiss"
# algo-1-jpiss_1  |     ],
# algo-1-jpiss_1  |     "hyperparameters": {
# algo-1-jpiss_1  |         "model_dir": "s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/model"
# algo-1-jpiss_1  |     },
# algo-1-jpiss_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-jpiss_1  |     "input_data_config": {
# algo-1-jpiss_1  |         "training": {
# algo-1-jpiss_1  |             "TrainingInputMode": "File"
# algo-1-jpiss_1  |         }
# algo-1-jpiss_1  |     },
# algo-1-jpiss_1  |     "input_dir": "/opt/ml/input",
# algo-1-jpiss_1  |     "is_master": true,
# algo-1-jpiss_1  |     "job_name": "tensorflow-training-2020-02-02-17-46-27-564",
# algo-1-jpiss_1  |     "log_level": 20,
# algo-1-jpiss_1  |     "master_hostname": "algo-1-jpiss",
# algo-1-jpiss_1  |     "model_dir": "/opt/ml/model",
# algo-1-jpiss_1  |     "module_dir": "s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/source/sourcedir.tar.gz",
# algo-1-jpiss_1  |     "module_name": "train",
# algo-1-jpiss_1  |     "network_interface_name": "eth0",
# algo-1-jpiss_1  |     "num_cpus": 2,
# algo-1-jpiss_1  |     "num_gpus": 0,
# algo-1-jpiss_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-jpiss_1  |     "output_dir": "/opt/ml/output",
# algo-1-jpiss_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-jpiss_1  |     "resource_config": {
# algo-1-jpiss_1  |         "current_host": "algo-1-jpiss",
# algo-1-jpiss_1  |         "hosts": [
# algo-1-jpiss_1  |             "algo-1-jpiss"
# algo-1-jpiss_1  |         ]
# algo-1-jpiss_1  |     },
# algo-1-jpiss_1  |     "user_entry_point": "train.py"
# algo-1-jpiss_1  | }
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | Environment variables:
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | SM_HOSTS=["algo-1-jpiss"]
# algo-1-jpiss_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-jpiss_1  | SM_HPS={"model_dir":"s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/model"}
# algo-1-jpiss_1  | SM_USER_ENTRY_POINT=train.py
# algo-1-jpiss_1  | SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# algo-1-jpiss_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-jpiss","hosts":["algo-1-jpiss"]}
# algo-1-jpiss_1  | SM_INPUT_DATA_CONFIG={"training":{"TrainingInputMode":"File"}}
# algo-1-jpiss_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-jpiss_1  | SM_CHANNELS=["training"]
# algo-1-jpiss_1  | SM_CURRENT_HOST=algo-1-jpiss
# algo-1-jpiss_1  | SM_MODULE_NAME=train
# algo-1-jpiss_1  | SM_LOG_LEVEL=20
# algo-1-jpiss_1  | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# algo-1-jpiss_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-jpiss_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-jpiss_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-jpiss_1  | SM_NUM_CPUS=2
# algo-1-jpiss_1  | SM_NUM_GPUS=0
# algo-1-jpiss_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-jpiss_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/source/sourcedir.tar.gz
# algo-1-jpiss_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1-jpiss","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-jpiss"],"hyperparameters":{"model_dir":"s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2020-02-02-17-46-27-564","log_level":20,"master_hostname":"algo-1-jpiss","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-jpiss","hosts":["algo-1-jpiss"]},"user_entry_point":"train.py"}
# algo-1-jpiss_1  | SM_USER_ARGS=["--model_dir","s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/model"]
# algo-1-jpiss_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-jpiss_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-jpiss_1  | SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/model
# algo-1-jpiss_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | Invoking script with the following command:
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | /usr/bin/python3 train.py --model_dir s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/model
# algo-1-jpiss_1  |
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | Starting the training.
# algo-1-jpiss_1  |                                                TITLE  ...      TIMESTAMP
# algo-1-jpiss_1  | 1  Fed official says weak data caused by weather,...  ...  1394470370698
# algo-1-jpiss_1  | 2  Fed's Charles Plosser sees high bar for change...  ...  1394470371207
# algo-1-jpiss_1  | 3  US open: Stocks fall after Fed official hints ...  ...  1394470371550
# algo-1-jpiss_1  | 4  Fed risks falling 'behind the curve', Charles ...  ...  1394470371793
# algo-1-jpiss_1  | 5  Fed's Plosser: Nasty Weather Has Curbed Job Gr...  ...  1394470372027
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | [5 rows x 7 columns]
# algo-1-jpiss_1  | Found 65990 unique tokens.
# algo-1-jpiss_1  | Shape of data tensor: (422417, 100)
# algo-1-jpiss_1  | Shape of label tensor: (422417, 4)
# algo-1-jpiss_1  | x_train shape:  (337933, 100)
# algo-1-jpiss_1  | Model: "sequential"
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | Layer (type)                 Output Shape              Param #
# algo-1-jpiss_1  | =================================================================
# algo-1-jpiss_1  | embedding (Embedding)        (None, 100, 100)          1000000
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | flatten (Flatten)            (None, 10000)             0
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | dense (Dense)                (None, 8)                 80008
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | dense_1 (Dense)              (None, 16)                144
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | dropout (Dropout)            (None, 16)                0
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | dense_2 (Dense)              (None, 32)                544
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | dense_3 (Dense)              (None, 4)                 132
# algo-1-jpiss_1  | =================================================================
# algo-1-jpiss_1  | Total params: 1,080,828
# algo-1-jpiss_1  | Trainable params: 1,080,828
# algo-1-jpiss_1  | Non-trainable params: 0
# algo-1-jpiss_1  | _________________________________________________________________
# algo-1-jpiss_1  | Train on 337933 samples, validate on 84484 samples
# algo-1-jpiss_1  | Epoch 1/2
# algo-1-jpiss_1  | 337933/337933 - 48s - loss: 1.3139 - acc: 0.3611 - val_loss: 1.3129 - val_acc: 0.3602
# algo-1-jpiss_1  | Epoch 2/2
# algo-1-jpiss_1  | 337933/337933 - 46s - loss: 1.3120 - acc: 0.3611 - val_loss: 1.3130 - val_acc: 0.3602
# algo-1-jpiss_1  | /opt/ml/input/data/training/model
# algo-1-jpiss_1  | Training complete. Now saving model to:  /opt/ml/input/data/training/model
# algo-1-jpiss_1  | Traceback (most recent call last):
# algo-1-jpiss_1  |   File "train.py", line 181, in train
# algo-1-jpiss_1  |     model.save(os.path.join(model_path, 'news_breaker.h5'))
# algo-1-jpiss_1  |   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/network.py", line 975, in save
# algo-1-jpiss_1  |     signatures, options)
# algo-1-jpiss_1  |   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/saving/save.py", line 112, in save_model
# algo-1-jpiss_1  |     model, filepath, overwrite, include_optimizer)
# algo-1-jpiss_1  |   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/saving/hdf5_format.py", line 92, in save_model_to_hdf5
# algo-1-jpiss_1  |     f = h5py.File(filepath, mode='w')
# algo-1-jpiss_1  |   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py", line 408, in __init__
# algo-1-jpiss_1  |     swmr=swmr)
# algo-1-jpiss_1  |   File "/usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py", line 179, in make_fid
# algo-1-jpiss_1  |     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
# algo-1-jpiss_1  |   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
# algo-1-jpiss_1  |   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
# algo-1-jpiss_1  |   File "h5py/h5f.pyx", line 108, in h5py.h5f.create
# algo-1-jpiss_1  | OSError: Unable to create file (unable to open file: name = '/opt/ml/input/data/training/model/news_breaker.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242)
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | During handling of the above exception, another exception occurred:
# algo-1-jpiss_1  |
# algo-1-jpiss_1  | Traceback (most recent call last):
# algo-1-jpiss_1  |   File "train.py", line 231, in <module>
# algo-1-jpiss_1  |     model = train(dataset, column_names, args.train)
# algo-1-jpiss_1  |   File "train.py", line 200, in train
# algo-1-jpiss_1  |     with open(os.path.join(base_dir+'/output', 'failure'), 'w') as s:
# algo-1-jpiss_1  | FileNotFoundError: [Errno 2] No such file or directory: '/opt/ml/input/data/training/output/failure'
# algo-1-jpiss_1  | 2020-02-02 17:48:33,686 sagemaker-containers ERROR    ExecuteUserScriptError:
# algo-1-jpiss_1  | Command "/usr/bin/python3 train.py --model_dir s3://sagemaker-us-east-1-731833107751/tensorflow-training-2020-02-02-17-46-27-564/model"
# algo-1-jpiss_1  | Traceback (most recent call last):
# algo-1-jpiss_1  |   File "/usr/local/bin/dockerd-entrypoint.py", line 24, in <module>
# algo-1-jpiss_1  |     subprocess.check_call(shlex.split(' '.join(sys.argv[1:])))
# algo-1-jpiss_1  |   File "/usr/lib/python3.6/subprocess.py", line 311, in check_call
# algo-1-jpiss_1  |     raise CalledProcessError(retcode, cmd)
# algo-1-jpiss_1  | subprocess.CalledProcessError: Command '['train']' returned non-zero exit status 1.
# tmp1jsw7rhh_algo-1-jpiss_1 exited with code 1
# Aborting on container exit...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     154         try:
# --> 155             _stream_output(process)
#     156         except RuntimeError as e:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/image.py in _stream_output(process)
#     672     if exit_code != 0:
# --> 673         raise RuntimeError("Process exited with code: %s" % exit_code)
#     674
#
# RuntimeError: Process exited with code: 1
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-b3174dee663f> in <module>()
# ----> 1 estimator.fit(training_data_uri)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config, run_tensorboard_locally)
#     461                 tensorboard.join()
#     462         else:
# --> 463             fit_super()
#     464
#     465     @classmethod
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit_super()
#     440
#     441         def fit_super():
# --> 442             super(TensorFlow, self).fit(inputs, wait, logs, job_name, experiment_config)
#     443
#     444         if run_tensorboard_locally and wait is False:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     459         self._prepare_for_training(job_name=job_name)
#     460
# --> 461         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     462         self.jobs.append(self.latest_training_job)
#     463         if wait:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1012             train_args["enable_sagemaker_metrics"] = estimator.enable_sagemaker_metrics
#    1013
# -> 1014         estimator.sagemaker_session.train(**train_args)
#    1015
#    1016         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image, algorithm_arn, encrypt_inter_container_traffic, train_use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics)
#     549         LOGGER.info("Creating training-job with name: %s", job_name)
#     550         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 551         self.sagemaker_client.create_training_job(**train_request)
#     552
#     553     def process(
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#      99         training_job = _LocalTrainingJob(container)
#     100         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
# --> 101         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#     102
#     103         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#      94
#      95         self.model_artifacts = self.container.train(
# ---> 96             input_data_config, output_data_config, hyperparameters, job_name
#      97         )
#      98         self.end_time = datetime.datetime.now()
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     158             # which contains the exit code and append the command line to it.
#     159             msg = "Failed to run: %s, %s" % (compose_command, str(e))
# --> 160             raise RuntimeError(msg)
#     161         finally:
#     162             artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#
# RuntimeError: Failed to run: ['docker-compose', '-f', '/tmp/tmp1jsw7rhh/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1
